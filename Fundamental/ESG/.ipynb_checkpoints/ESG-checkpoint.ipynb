# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from xbbg import blp

# %%
def GetRet(Liste, Start = "20150101"):
    Start = "20150101"
    End = pd.Timestamp.today().strftime("%Y%m%d")

    Res = blp.bdh(tickers= [x + " Equity" for x in Liste],start_date = Start , end_date = End)
    Res.columns = [x[0] for x in Res.columns]
    Ret = (np.log(Res) - np.log(Res.shift(1))).iloc[1:,:]
    Ret = Ret.T.mean()
    return Ret

def GetBench(Index, Start = "20150101"):
    Res = blp.bdh(tickers= Index + " Index",start_date = Start , end_date = End)
    Ret = (np.log(Res) - np.log(Res.shift(1))).iloc[1:,:]
    Ret.columns = [Index]
    return Ret

def Plot(Ret):
    Ret = Ret + 1
    if type(Ret) == type(pd.Series(0)):
        Ret[0] = 100
    else:
        Ret.iloc[0,0] = 100
    plt.plot(Ret.cumprod())

# %% [markdown]
# # Using Bloomberg analysis

# %%
df = pd.read_csv("ESG.csv", index_col=1).iloc[:,1:]
df.iloc[:5,:]

# *The Historical values compare to 5 years ago
# Out:
#           Environmental Vs History Environmental Vs Peers Social Vs History  \
# Companies
# A UN                        Better                  Worse           Neutral
# AAL UW                      Better                  Worse            Better
# AAP UN                     Neutral                Neutral           Neutral
# AAPL UW                      Worse                 Better           Neutral
# ABBV UN                     Better                 Better           Neutral
#
#           Social Vs Peers Governance Vs History Governance Vs Peers
# Companies
# A UN              Neutral                Better               Worse
# AAL UW            Neutral                 Worse               Worse
# AAP UN             Better                Better             Neutral
# AAPL UW           Neutral                 Worse               Worse
# ABBV UN            Better                 Worse               Worse

# %%
EnvironmentalListe = df[df.iloc[:,0] == "Better"][df.iloc[:,1] == "Better"].index
SocialListe = df[df.iloc[:,2] == "Worse"][df.iloc[:,3] == "Worse"].index
GovernanceListe = df[df.iloc[:,4] == "Worse"][df.iloc[:,5] == "Worse"].index
# Out:
# C:\Users\HanaDT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\HanaDT\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\HanaDT\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\HanaDT\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """

# %%
# Getting for Each part of ESG
Environmental = GetRet(EnvironmentalListe)
Social = GetRet(SocialListe)
Governance = GetRet(GovernanceListe)

# Using S&P  as a benchmark
Bench = GetBench("SPX")

# %%
i = 2

Long = df[df.iloc[:,i] == "Better"][df.iloc[:,i+1] == "Better"].index
Short = df[df.iloc[:,i] == "Worse"][df.iloc[:,i+1] == "Worse"].index

IndexLong = GetRet(Long)
IndexShort = GetRet(Short)

spread = IndexLong - IndexShort
# Out:
# C:\Users\HanaDT\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\HanaDT\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
Plot(Bench)
Plot(IndexLong)
Plot(IndexShort)
Plot(spread)
plt.legend(["Bench", "Long", "Short","Spread"])
plt.show()

# %%
Plot(Bench)
Plot(IndexLong)
Plot(IndexShort)
Plot(spread)
plt.legend(["Bench", "Long", "Short","Spread"])
plt.show()

# %%
Plot(Bench)
Plot(Environmental)
Plot(Social)
Plot(Governance)
plt.legend(["Bench", "Environmental", "Social","Governance"])
plt.show()

# %% [markdown]
# # Using ESG ETF

# %%
# US
ESGU = GetRet(["ESGU US"], Start= "2017/01/01")
ESG = GetRet(["ESG US"], Start= "2017/01/01")
ESGV = GetRet(["ESGV US"], Start= "2017/01/01")

# Europe
ESGE = GetRet(["ESGE FP"])
EUSI = getBench("EUSI")

# Using S&P  as a benchmark
Bench = GetBench("SPX", Start= "2017/01/01")

# %%
# Formating

ESGU = ESGU[ESGU.index.year >= 2017]
ESG = ESG[ESG.index.year >= 2017]

# %%
Plot(Bench)
Plot(ESGU)
Plot(ESG)

plt.legend(["SPX", "ESGU", "ESG"])
plt.plot()
# Out:
# []

# %%
Long
# Out:
# Index(['ADSK UW', 'AES UN', 'ALK UN', 'AMZN UW', 'APD UN', 'BKR UN', 'BLK UN',
#        'BLL UN', 'CAG UN', 'CAT UN', 'CF UN', 'CI UN', 'CL UN', 'CMG UN',
#        'COP UN', 'CPRI UN', 'CSX UW', 'CTAS UW', 'CVX UN', 'CXO UN', 'D UN',
#        'DTE UN', 'ED UN', 'EMR UN', 'ES UN', 'FLS UN', 'FMC UN', 'GIS UN',
#        'GL UN', 'GLW UN', 'HBAN UW', 'HD UN', 'HFC UN', 'HIG UN', 'HSIC UW',
#        'HST UN', 'INTC UW', 'INTU UW', 'K UN', 'KMB UN', 'L UN', 'LH UN',
#        'LIN UN', 'LKQ UW', 'LNT UW', 'LUV UN', 'MAR UW', 'MOS UN', 'MRK UN',
#        'NRG UN', 'NVDA UW', 'ORCL UN', 'PEG UN', 'PPL UN', 'RTN UN', 'STX UW',
#        'STZ UN', 'SWKS UW', 'TFX UN', 'UNP UN', 'UPS UN', 'UTX UN', 'WHR UN',
#        'WRK UN'],
#       dtype='object', name='Companies')

# %%
Short
# Out:
# Index(['ABC UN', 'ARNC UN', 'AVB UN', 'BA UN', 'CBOE UF', 'CMI UN', 'EMN UN',
#        'EQIX UW', 'EXPE UW', 'FANG UW', 'FCX UN', 'FE UN', 'FRC UN', 'HAL UN',
#        'HUM UN', 'INFO UN', 'IVZ UN', 'KSU UN', 'LVS UN', 'MHK UN', 'MPC UN',
#        'MS UN', 'NEM UN', 'NTRS UW', 'NWL UW', 'PKG UN', 'PSX UN', 'RL UN',
#        'SJM UN', 'SLG UN', 'TAP UN', 'UHS UN', 'URI UN', 'WEC UN', 'WMB UN',
#        'WMT UN', 'XEL UW'],
#       dtype='object', name='Companies')

# %%
import pandas as pd

# %%
SGESG = pd.read_clipboard()

# %%
SGESG
# Out:
#                            Name                         Industry  \
# 0                           ABB                    Capital Goods
# 1                        AbbVie  Pharmaceuticals & Biotechnology
# 2                     Accenture           Software & IT Services
# 3                         Accor     Hotels Restaurants & Leisure
# 4        Ackermans & van Haaren   Holding & Investment companies
# ...                         ...                              ...
# 7041   Yapi Ve Kredi Bankasi AS                       Financials
# 7042     Yara International ASA                        Materials
# 7043                 Ziggo N.V.       Telecommunication Services
# 7044        Zodiac Aerospace SA                      Industrials
# 7045  Zurich Insurance Group AG                       Financials
#
#                Ticker  Total Governance Social Environment    Date
# 0     ABLZF US Equity   76.5       67.6   81.4        82.5  Sep-19
# 1      ABBV US Equity   60.2       52.6   61.5        85.0  Sep-19
# 2       ACN US Equity   74.3       68.1   82.3        70.0  Sep-19
# 3     ACRFF US Equity   69.5       61.6   77.2        75.0  Sep-19
# 4     AVHNF US Equity   50.8       46.3   52.9        62.0  Sep-19
# ...               ...    ...        ...    ...         ...     ...
# 7041  YVKBF US Equity   35.0       20.0   90.0         0.0  Sep-12
# 7042  YRAIF US Equity   52.6       80.0   54.0        32.1  Sep-12
# 7043  ZIGGF US Equity   50.0       66.7   81.3         6.3  Sep-12
# 7044  ZODFF US Equity   56.3       63.9   62.5        25.0  Sep-12
# 7045  ZFSVF US Equity   73.5       80.6   60.0        50.0  Sep-12
#
# [7046 rows x 8 columns]

# %%
SGESG.to_csv("SGesg.csv", index=False)

# %%
type(SGESG.Date.unique()[0])
# Out:
# str
