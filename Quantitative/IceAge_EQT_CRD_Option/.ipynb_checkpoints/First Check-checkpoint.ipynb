# %% [markdown]
# # CDS Index Vs. Equity Options

# %% [markdown]
# ### Rationale

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from xbbg import blp

# %%
def Plot(Ret):
    print("Sharpe", np.sqrt(252) * Ret.mean()/Ret.std())
    Ret = Ret + 1
    if type(Ret) == type(pd.Series(0)):
        Ret[0] = 100
    else:
        Ret.iloc[0,0] = 100
    plt.plot(Ret.cumprod())
    plt.axvline(x=pd.to_datetime("2020-03-09"), c="k")
    plt.show()
    return "Plot!"

# %%
# Get Data

Start = "20000101"
End = ""

TickerList = ["ITRXTX5I Index", "PUTWD=2 OC Equity"]

TickerList = ["IBOXHY Index", "PUT Index"]

df = blp.bdh(TickerList, "PX_Last", start_date=Start)
df.columns = ["IBOXX", "SPPuts"]

# %%
Ret = (np.log(df) - np.log(df.shift(1))).dropna()

# %%
# Ret = (np.log(df) - np.log(df.shift(1)))#.dropna()
# Strat = - Ret["S&PPuts"] + Ret["IBOXX"]
# Strat = Strat + 1
# Strat[0] = 100
# Strat.index = pd.to_datetime(Strat.index)

# %%
# plt.plot(Strat.cumprod())
# plt.xticks(rotation=45)

# %%
plt.plot(Ret.cumsum())
plt.legend(Ret.columns)
plt.show()

# %%
#Ret["Diff"] = Ret.IBOXX - Ret["S&PPuts"]

# %%
Ret = Ret.dropna()

# %%
dico = {}
for x in range(len(Ret) - 252):
    dico[Ret.index[252+x]] = Ret.iloc[x:x+252].corr().iloc[1,0]

# %%
Returns = pd.concat((Ret, pd.Series(dico)), axis = 1)
Returns.columns = ["IBOXX", "SPPuts", "Correl"]
